# %%
name = 'Matheus'
cidade = 'Itajaí'
anoNascimento = 1997

# %%
print(f'Meu nome é {name}, sou de {cidade}, e nasci em {anoNascimento}')
# Out:
# Meu nome é Matheus, sou de Itajaí, e nasci em 1997

# %%
nome = 'josé'
nota = 6

if nota >= 7:
    print(f'{nome} passou')
elif nota ==6:
    print(f'{nome} ficou na média mas precisa estudar mais')
else:
    print(f'{nome} reprovou')
# Out:
# josé ficou na média mas precisa estudar mais

# %%
def media(nota1, nota2, aluno='desconhecido'):
    media = (nota1 + nota2)/2
    print(f'{aluno} média é {media}')

media (7,8,'Katarina')
media (5,6,'José')
media (7,8)
# Out:
# Katarina média é 7.5
# José média é 5.5

# %%
alunos = ['maria','ana','josé','Katarina']
for i in alunos:
    print(i)
# Out:
# maria
# ana
# josé
# Katarina

# %%
aluno = {'nome': 'Maria', 'nota':10}
print(type(aluno))
# Out:
# <class 'dict'>

# %%
import requests 

response = requests.get('https://dummyjson.com/users')

print(response.json()['users'][0]['firstName'])
# Out:
# Emily

# %%
tamanho = len(response.json()['users'])

# %%
usuarios_lista = response.json()['users']
for i in range(tamanho):
    print(f'{usuarios_lista[i]["firstName"]} {usuarios_lista[i]["lastName"]} - idade: {usuarios_lista[i]["age"]}')
    if usuarios_lista[i]["age"] >= 30:
        print('Essa pessoa tem mais de 30!')
    else:
        print('Essa pessoa tem menos de 30!')
# Out:
# Emily Johnson - idade: 29
# Essa pessoa tem menos de 30!
# Michael Williams - idade: 36
# Essa pessoa tem mais de 30!
# Sophia Brown - idade: 43
# Essa pessoa tem mais de 30!
# James Davis - idade: 46
# Essa pessoa tem mais de 30!
# Emma Miller - idade: 31
# Essa pessoa tem mais de 30!
# Olivia Wilson - idade: 23
# Essa pessoa tem menos de 30!
# Alexander Jones - idade: 39
# Essa pessoa tem mais de 30!
# Ava Taylor - idade: 28
# Essa pessoa tem menos de 30!
# Ethan Martinez - idade: 34
# Essa pessoa tem mais de 30!
# Isabella Anderson - idade: 32
# Essa pessoa tem mais de 30!
# Liam Garcia - idade: 30
# Essa pessoa tem mais de 30!
# Mia Rodriguez - idade: 25
# Essa pessoa tem menos de 30!
# Noah Hernandez - idade: 41
# Essa pessoa tem mais de 30!
# Charlotte Lopez - idade: 37
# Essa pessoa tem mais de 30!
# William Gonzalez - idade: 33
# Essa pessoa tem mais de 30!
# Avery Perez - idade: 26
# Essa pessoa tem menos de 30!
# Evelyn Sanchez - idade: 38
# Essa pessoa tem mais de 30!
# ...

# %%
dados_dic = {"nome": "Ana", "idade": 29, "ativo":True} ,{"nome": "Malu", "idade": 23, "ativo":False}
## para dics:
for key, value, in dados_dic():
    print(key,value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 dados_dic = {"nome": "Ana", "idade": 29, "ativo":True} ,{"nome": "Malu", "idade": 23, "ativo":False}
#       2 ## para dics:
# ----> 3 for key, value, in dados_dic(i):
#       4     print(key,value)
#
# NameError: name 'i' is not defined
